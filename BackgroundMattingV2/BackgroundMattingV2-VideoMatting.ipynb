# %%
# !gdown https://drive.google.com/uc?id=1tCEk8FE3WGrr49cdL8qMCqHptMCAtHRU -O inputs/src.mp4
# !gdown https://drive.google.com/uc?id=1wAR3JjnTO60B_DUr7ruIJj0Z2pcIGkyP -O inputs/bgr.png
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tCEk8FE3WGrr49cdL8qMCqHptMCAtHRU
# To: d:\Product_id github\BackgroundMattingV2\inputs\src.mp4
#
#   0%|          | 0.00/16.0M [00:00<?, ?B/s]
#   3%|▎         | 524k/16.0M [00:00<00:06, 2.49MB/s]
#  10%|▉         | 1.57M/16.0M [00:00<00:02, 5.65MB/s]
#  23%|██▎       | 3.67M/16.0M [00:00<00:01, 11.0MB/s]
#  33%|███▎      | 5.24M/16.0M [00:00<00:01, 8.45MB/s]
#  46%|████▌     | 7.34M/16.0M [00:00<00:00, 10.8MB/s]
#  56%|█████▌    | 8.91M/16.0M [00:01<00:01, 6.33MB/s]
#  72%|███████▏  | 11.5M/16.0M [00:01<00:00, 8.98MB/s]
#  82%|████████▏ | 13.1M/16.0M [00:01<00:00, 6.19MB/s]
#  95%|█████████▌| 15.2M/16.0M [00:01<00:00, 8.14MB/s]
# 100%|██████████| 16.0M/16.0M [00:02<00:00, 7.91MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1wAR3JjnTO60B_DUr7ruIJj0Z2pcIGkyP
# To: d:\Product_id github\BackgroundMattingV2\inputs\bgr.png
#
#   0%|          | 0.00/1.10M [00:00<?, ?B/s]
# ...

# %%
# !gdown https://drive.google.com/uc?id=1ErIAsB_miVhYL9GDlYUmfbqlV293mSYf -O weights/pytorch_resnet50.pth
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ErIAsB_miVhYL9GDlYUmfbqlV293mSYf
# From (redirected): https://drive.google.com/uc?id=1ErIAsB_miVhYL9GDlYUmfbqlV293mSYf&confirm=t&uuid=60595898-3bd7-4be8-bbe9-2b1b7fea94b1
# To: d:\Product_id github\BackgroundMattingV2\weights\pytorch_resnet50.pth
#
#   0%|          | 0.00/161M [00:00<?, ?B/s]
#   0%|          | 524k/161M [00:00<00:41, 3.87MB/s]
#   1%|          | 1.57M/161M [00:00<00:22, 7.07MB/s]
#   3%|▎         | 4.72M/161M [00:00<00:10, 15.0MB/s]
#   4%|▍         | 6.29M/161M [00:00<00:15, 10.1MB/s]
#   5%|▍         | 7.86M/161M [00:00<00:19, 7.77MB/s]
#   6%|▋         | 10.5M/161M [00:01<00:13, 11.3MB/s]
#   7%|▋         | 12.1M/161M [00:01<00:12, 11.5MB/s]
#   8%|▊         | 13.6M/161M [00:01<00:12, 11.9MB/s]
#   9%|▉         | 15.2M/161M [00:01<00:12, 12.0MB/s]
#  10%|█         | 16.8M/161M [00:01<00:15, 9.62MB/s]
#  12%|█▏        | 18.9M/161M [00:01<00:12, 11.7MB/s]
# ...

# %%
# !python inference_video.py \
        --model-type mattingrefine \
        --model-backbone resnet50 \
        --model-backbone-scale 0.25 \
        --model-refine-mode sampling \
        --model-refine-sample-pixels 80000 \
        --model-checkpoint "weights/pytorch_resnet50.pth" \
        --video-src "inputs/rsrc.mp4" \
        --video-bgr "inputs/bgr.png" \
        --output-dir "outputs/" \
        --device "cpu" \
        --output-type com fgr pha err ref
# Out:
# ^C
